# %% [markdown]
# # Clase 1 Pasos Basicos

# %% [markdown]
# ## We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
print('hola')
# Out:
# hola

# %%
# %ls
# Out:
# 07_02_pie_box_scatter_bubble.ipynb  README.md         runtime.txt
# Canada.xlsx                         requierementsEXL  welcome_binder.ipynb
# nhanes_2015_2016.csv                requirements.txt

# %%
#%magic # estos son las funciones de magia de jypter notebook
# Out:
# UsageError: Line magic function `%magi` not found.

# %%
nombre = 'My name'
nombre
# Out:
# 'My name'

# %%
# %pwd
# Out:
# '/home/jovyan'

# %%
import numpy as np

# %%
N = 50
X = np.random.rand(N)
X
# Out:
# array([0.04230988, 0.50803161, 0.15998855, 0.03157652, 0.652182  ,
#        0.53110519, 0.97329872, 0.46954724, 0.27622597, 0.3729746 ,
#        0.2200654 , 0.69883019, 0.31241386, 0.93825887, 0.53421374,
#        0.22549248, 0.70595559, 0.57634175, 0.83908475, 0.39648959,
#        0.66224925, 0.50572614, 0.44140578, 0.23030878, 0.70175695,
#        0.36108451, 0.17968872, 0.79256741, 0.61282166, 0.67599048,
#        0.82099228, 0.8340031 , 0.15522688, 0.26332231, 0.83169174,
#        0.48405035, 0.44175678, 0.29461288, 0.37415711, 0.2453685 ,
#        0.17142407, 0.38419313, 0.70436924, 0.77844025, 0.38095364,
#        0.50535513, 0.68373622, 0.76483701, 0.46042541, 0.77531793])

# %%
##Typos de data en python

# %%
import math

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
math.pi
# Out:
# 3.141592653589793

# %%
type(nombre)
# Out:
# str

# %%
type(math.pi)
# Out:
# float

# %%
type('math.pi')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(-3)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type(2/3)
# Out:
# float

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
suma = sum(numbers)
suma
# Out:
# 15

# %%
length_numbers=len(numbers)
length_numbers
# Out:
# 5

# %%
promedio = suma/length_numbers
promedio
# Out:
# 3.0

# %%
# 60 * 10^(-2)

# %%
type(bool('yes'))
# Out:
# bool

# %%
type(6<5)
# Out:
# bool

# %%
a_list = [True, 6<5, 1==3, None is None, 2, 'Name', 4.0, 2/3]
a_list
# Out:
# [True, False, False, True, 2, 'Name', 4.0, 0.6666666666666666]

# %%
x = 5
y = 6 
if x<y:
    print('{} es menor que {}'.format(x,y))
else:
        print('{} es mayor que {}'.format(x,y))
# Out:
# 5 es menor que 6

# %%
if x<y
print
